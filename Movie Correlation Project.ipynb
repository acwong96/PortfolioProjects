# %%
# Import Librares

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# Read data
df = pd.read_csv(r'D:\Download\archive\movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#Check for missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
#Check data types for columns

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Convert data type of column for readability

df['budget'] = df['budget'].astype('Int64')
df['gross'] = df['gross'].astype('Int64')

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#Create correct Year Column
import re
df['yearcorrect'] = df['released'].astype(str).str.split().str[2:3]
#df['yearcorrect'] = re.findall(r",(\d+)", df['released'].astype(str))
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.sort_values(by=['gross'],inplace = False, ascending = False)
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
# ...                                          ...    ...     ...   ...
# 7663                                More to Life    NaN   Drama  2020
# 7664                                 Dream Round    NaN  Comedy  2020
# 7665                               Saving Mbango    NaN   Drama  2020
# 7666                                It's Just Us    NaN   Drama  2020
# 7667                                   Tee em el    NaN  Horror  2020
#
#                                released  score      votes       director  \
# ...

# %%
#df.fillna(0)
#df["rating"].str.replace('','Not_available')
#df["rating"].str.replace('[^a-zA-Z0-9]','',regex=True)
#df["rating"].apply(lambda x: str(x))

#df["rating"] = df["rating"].replace(np.nan, '')
df[['budget', 'gross']] = df[['budget', 'gross']].fillna(0)

# %%
#Drop duplicates

df['name'].drop_duplicates()
# Out:
# 0                                          The Shining
# 1                                      The Blue Lagoon
# 2       Star Wars: Episode V - The Empire Strikes Back
# 3                                            Airplane!
# 4                                           Caddyshack
#                              ...
# 7663                                      More to Life
# 7664                                       Dream Round
# 7665                                     Saving Mbango
# 7666                                      It's Just Us
# 7667                                         Tee em el
# Name: name, Length: 7512, dtype: object

# %%
#Scatter plot of budget vs gross

plt.scatter(x=df['budget'],y=df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earning')
plt.ylabel('Budget for Film')
plt.show()

# %%
#Plot budget vs gross using seaborn
#df['budget'] = pd.to_numeric(df['budget'], errors='coerce').fillna(0).astype(int)
#df['gross'] = pd.to_numeric(df['gross'], errors='coerce').fillna(0).astype(int) 
sns.regplot(x='budget',y='gross',data=df, scatter_kws={"color": "red"},line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
#Finding correlation from data
df.corr(numeric_only=True)
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.309212  0.261092  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.173680  0.399451
# votes    0.222945  0.409182  1.000000  0.486862  0.588068  0.309212
# budget   0.309212  0.055665  0.486862  1.000000  0.704237  0.269510
# gross    0.261092  0.173680  0.588068  0.704237  1.000000  0.210915
# runtime  0.120811  0.399451  0.309212  0.269510  0.210915  1.000000

# %%
correlation_matrix = df.corr(numeric_only=True)
sns.heatmap(correlation_matrix, annot=True)
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\categorical.py:425, in Categorical.__init__(self, values, categories, ordered, dtype, fastpath, copy)
#     424 try:
# --> 425     codes, categories = factorize(values, sort=True)
#     426 except TypeError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\algorithms.py:780, in factorize(values, sort, use_na_sentinel, size_hint)
#     778             values = np.where(null_mask, na_value, values)
# --> 780     codes, uniques = factorize_array(
#     781         values,
#     782         use_na_sentinel=use_na_sentinel,
#     783         size_hint=size_hint,
#     784     )
#     786 if sort and len(uniques) > 0:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\algorithms.py:581, in factorize_array(values, use_na_sentinel, size_hint, na_value, mask)
# ...

# %%
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     6587       7      6  1980      1706    8.4   927000.0      2589    4015
# 1     5573       7      1  1980      1493    5.8    65000.0      2269    1633
# 2     5142       5      0  1980      1772    8.7  1200000.0      1111    2568
# 3      286       5      4  1980      1493    7.7   221000.0      1301    2001
# 4     1027       7      4  1980      1544    7.3   108000.0      1054     522
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7663  3705       0      6  2020      2965    3.1       18.0      1500    2290
# 7664  1678       0      4  2020      1108    4.7       36.0       774    2615
# 7665  4717       0      6  2020       194    5.7       29.0      2061    2684
# 7666  2843       0      6  2020      2818    NaN        NaN      1184    1825
# 7667  5394       0     10  2020       392    5.7        7.0      2165    3345
#
# ...
